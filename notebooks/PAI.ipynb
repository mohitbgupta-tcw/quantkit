# %%
# configs
# {   
#     "as_of_date": "12/31/2023",
#     "exchange_rate": 0.9802,
#     "API_settings": {
#         "snowflake_parameters": {
#             "user": "user",
#             "password": "password"
#         }
#     }
# }

# %%
# import quantkit.runners.runner_PAI as runner

# local_configs = "C:\\Users\\bastit\\Documents\\quantkit\\configs\\configs_PAI.json"

# r = runner.Runner()
# r.init(local_configs=local_configs)
# r.run()

# %%
# add quantkit to path
import sys
from pathlib import Path
d = Path().resolve().parent.parent
sys.path.insert(0, str(d))

# %%
import warnings
warnings.filterwarnings("ignore")
import quantkit.handyman.pai as pai

local_configs = "C:\\Users\\bastit\\OneDrive - The TCW Group Inc\\Documents\\quantkit\\configs\\configs_PAI.json"

df_pai = pai.principal_adverse_impact(local_configs)
# Out:
# 2024-04-05 12:37:58,162  WORKING ON: Loading Portfolio Data
# 2024-04-05 12:38:08,431  WORKING ON: Batch 1/8
# ...

# %%
# df_pai.to_excel("PAI_dec2023.xlsx", index=False)

# %%
import quantkit.handyman.pai as pai

local_configs = "C:\\Users\\bastit\\OneDrive - The TCW Group Inc\\Documents\\quantkit\\configs\\configs_PAI.json"

df_data = pai.principal_adverse_data_points(local_configs)
# Out:
# 2024-04-05 12:38:49,392  WORKING ON: Loading Portfolio Data
# 2024-04-05 12:38:58,731  WORKING ON: Batch 1/8
# ...

# %%
# df_data.to_excel("raw_data_dec2023.xlsx", index=False)
